# %%
import csv
import os
import sys
import itertools
import numpy as np
import matplotlib.pyplot as plt
import requests
import pprint
import json
import glob
import pandas as pd
from requests.adapters import HTTPAdapter
import sys
# !{sys.executable} -m pip install python-usda
from usda import UsdaClient
from requests.packages.urllib3.util.retry import Retry
import re
from collections import defaultdict
# Out:
# Requirement already satisfied: python-usda in /Users/irisliu/.pyenv/versions/3.6.8/lib/python3.6/site-packages (0.4.6)
# Requirement already satisfied: requests>=2.16.0 in /Users/irisliu/.pyenv/versions/3.6.8/lib/python3.6/site-packages/requests-2.23.0-py3.6.egg (from python-usda) (2.23.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/irisliu/.pyenv/versions/3.6.8/lib/python3.6/site-packages/certifi-2020.4.5.1-py3.6.egg (from requests>=2.16.0->python-usda) (2020.4.5.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/irisliu/.pyenv/versions/3.6.8/lib/python3.6/site-packages/chardet-3.0.4-py3.6.egg (from requests>=2.16.0->python-usda) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /Users/irisliu/.pyenv/versions/3.6.8/lib/python3.6/site-packages/idna-2.9-py3.6.egg (from requests>=2.16.0->python-usda) (2.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/irisliu/.pyenv/versions/3.6.8/lib/python3.6/site-packages/urllib3-1.25.9-py3.6.egg (from requests>=2.16.0->python-usda) (1.25.9)
# You are using pip version 18.1, however version 20.3.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %% [markdown]
# #### USDA API Credential

# %%
### USDA Client Key ###
# client = UsdaClient('ohrJBZWi8Ggdf00mMWbax5fTBFc4mRm0i8kFGu6D')
client = UsdaClient('5jy6h1p6kZf5UX6aBXdQr2frrtfvNZKNZrsyxCei')
USDA_API_KEY = '5jy6h1p6kZf5UX6aBXdQr2frrtfvNZKNZrsyxCei'

# %% [markdown]
# #### Import and Read Validation Data

# %%
validation_set = pd.read_csv('Annual_Data.csv', encoding= 'unicode_escape')  
print("Size of Validation Set: {}".format(len(validation_set.index)))
validation_set
# Out:
# Size of Validation Set: 30120
# /Users/irisliu/.pyenv/versions/3.6.8/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (32,33,34,37) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#        Menu_Item_ID  Restaurant           Food_Category  \
# 0            100054       Qdoba                 Entrees
# 1            100057       Qdoba              Sandwiches
# 2            100060       Qdoba              Sandwiches
# 3            100073       Qdoba  Toppings & Ingredients
# 4             10012  Applebee's                    Soup
# ...             ...         ...                     ...
# 30115         99835   Pizza Hut                   Pizza
# 30116         99966     Popeyes                 Entrees
# 30117         99968     Popeyes                 Entrees
# 30118         99969     Popeyes                 Entrees
# 30119         99971     Popeyes              Sandwiches
#
#                                           Item_Name_2018  \
# 0                                           Burrito Bowl
# 1                                   Quesadilla Kids Meal
# 2                                                Burrito
# 3                                Flour Tortilla, 12.5 in
# 4                                      French Onion Soup
# ...                                                  ...
# 30115  Buffalo Chicken Pizza on Hand Tossed Crust, La...
# 30116                               Tenders Family Meals
# 30117                                3 Cajun Fish Filets
# 30118                              Fish & Popcorn Shrimp
# 30119                                     Seafood Po Boy
#
#                                    Item_Description_2018  Serving_Size_2018  \
# 0      Burrito Bowl, Burritos & More, Vegetarian Eats...                NaN
# 1      Quesadilla Kids Meal w/ Quesadilla, Applesauce...                NaN
# 2      Burrito, Burritos & More, Vegetarian Eats; Cho...                NaN
# 3       Flour Tortilla, 12.5 in, Ingredients for Entrees              102.0
# 4      French Onion Soup w/ Melted Cheese & Croutons,...                NaN
# ...                                                  ...                ...
# 30115  Buffalo Chicken Pizza w/ Buffalo Pizza Sauce, ...                NaN
# 30116  Tenders Family Meals w/ Handcrafted Tenders, S...                NaN
# 30117  3 Cajun Fish Filets, Seafood, Not Available At...                NaN
# 30118   Fish & Popcorn Shrimp w/ Side & Biscuit, Seafood                NaN
# 30119  Seafood Po Boy on French Baguette w/ Lettuce, ...                NaN
#
#       Serving_Size_text_2018 Serving_Size_Unit_2018  \
# 0                        NaN                    NaN
# 1                        NaN                    NaN
# 2                        NaN                    NaN
# 3                        NaN                      g
# 4                        NaN                    NaN
# ...                      ...                    ...
# 30115                    NaN                    NaN
# 30116                    NaN                    NaN
# 30117                    NaN                    NaN
# 30118                    NaN                    NaN
# 30119                    NaN                    NaN
#
#       Serving_Size_household_2018  Calories_2018  ...  Sodium_text_2018  \
# 0                             NaN            NaN  ...               NaN
# 1                             NaN            NaN  ...               NaN
# 2                             NaN            NaN  ...               NaN
# 3                             NaN          300.0  ...               NaN
# 4                             NaN          380.0  ...               NaN
# ...                           ...            ...  ...               ...
# 30115                     1 Slice          270.0  ...               NaN
# 30116                         NaN            NaN  ...               NaN
# 30117                    3 Pieces          380.0  ...               NaN
# 30118                         NaN            NaN  ...               NaN
# 30119                         NaN            NaN  ...               NaN
#
#        Potassium_text_2018  Carbohydrates_text_2018  Protein_text_2018  \
# 0                      NaN                      NaN                NaN
# 1                      NaN                      NaN                NaN
# 2                      NaN                      NaN                NaN
# 3                      NaN                      NaN                NaN
# 4                      NaN                      NaN                NaN
# ...                    ...                      ...                ...
# 30115                  NaN                      NaN                NaN
# 30116                  NaN                      NaN                NaN
# 30117                  NaN                      NaN                NaN
# 30118                  NaN                      NaN                NaN
# 30119                  NaN                      NaN                NaN
#
#        Sugar_text_2018  Dietary_Fiber_text_2018  Kids_Meal_2018  \
# 0                  NaN                      NaN               0
# 1                  NaN                      NaN               1
# 2                  NaN                      NaN               0
# 3                  NaN                      NaN               0
# 4                  NaN                      NaN               0
# ...                ...                      ...             ...
# 30115              NaN                      NaN               0
# 30116              NaN                      NaN               0
# 30117              NaN                      NaN               0
# 30118              NaN                      NaN               0
# 30119              NaN                      NaN               0
#
#        Limited_Time_Offer_2018  Regional_2018  Shareable_2018
# 0                            0              0               0
# 1                            0              0               0
# 2                            0              0               0
# 3                            0              0               0
# 4                            0              0               0
# ...                        ...            ...             ...
# 30115                        0              0               0
# 30116                        0              0               1
# 30117                        0              0               0
# 30118                        0              0               0
# 30119                        0              0               0
#
# [30120 rows x 46 columns]

# %% [markdown]
# ## 1. Clean Dataset by filtering drink items

# %%
drink_corpus = ['wine', 'white', 'rosé', 'drink', 'drinks', 'red', 'cocktail', 'martinis', 'sparkling', 
                'cocktails', 'beverages', 'bptmargaritas', 'beer', 'sangria', 'tequila', 'anejo', 
               'mezcal', 'reposado', 'blanco / Plata', 'Aguas Frescas', 'bloodymary&mimosacart', 
                'seasonalspritz', 'aguafrescas', 'californiachardonnay', 'Italian White', 'French White', 
                'Cabernet', 'Italian Red', 'California Merlot', 'Pinot Noir', 'Bordeaux Red', 'White Wine', 
                'Red Wine', 'Rose / Sparkling', 'On Tap', 'Proudly Serving Forster & Burnett','Bubbles','Margaritas','Chardonnay','Vinos','Pinot Grigio','Sauvignon Blanc','Rose','Cócteles','Malbec','Cervezas','Bottled','Draft','Wines By the Glass','Margarita Pitchers','Tequila Shots',
                'Draught Beer', 'Old World Reds', 'Bottles & Cans', 'Eclectic Reds - New World', 'Cabernet Sauvignon', 'Bordeaux Blend', 'Prosecco', 'Champagne'
                'soda', 'coffee', 'Iced Tea', 'Aquas Frescas', 'Xv Coffee', 'merlot', 'coffee', 'Juice, Coffee and Tea'
               ]
# drink_corpus = pd.read_csv('drinks_corpus.csv', delimiter=',', sep='\t', header=None)

def is_drink_item(item):
    item = str(item)
    clean_food_string = re.sub('\W+','', item.lower())
    for key in drink_corpus:
        clean_key = re.sub('\W+','', key.lower())
        if clean_food_string.find(clean_key) != -1 and clean_food_string == clean_key:
#             print('>>>>Filtered...: ', item)
            return True
    return False

# %% [markdown]
# ## 2. Search for food items' nutrition using USDA API

# %%
def usda_food_search(item):
    url = 'https://api.nal.usda.gov/fdc/v1/foods/search?api_key='+ USDA_API_KEY
    # USDA_API_KEY
    headers={'Content-type':'application/json', 'Accept':'application/json'}
    data = {
      "query": item,
      "pageSize": 25,
      "sortBy": "dataType.keyword",
      "sortOrder": "asc"
    }
    r = requests.post(url=url, json=data, headers=headers)
    if r.status_code == 200:
        result = r.json()
        return result
    return None

# %%
food_dict = defaultdict(list)
menu_files_folder_name = 'validation_nutrient_report_Dec_15' #### Change the name here for the nutrient report from USDA ####
if not os.path.exists(menu_files_folder_name):
    os.makedirs(menu_files_folder_name)
    
def scan_food_item_from_main_section(validation_set):
    food_items = validation_set[' Item_Name_2018']
    location_names = validation_set['Restaurant']
    for index, food_item in enumerate(food_items):
        if not is_drink_item(food_item):
            nut={}
            nut1={}
            count=0
            d={}
            main_nut=["energy","protein","total lipid (fat)","carbohydrate","fiber","sodium","cholesterol"]

            #To get the nutrient decomposition for each.
            nut = {"energy":0,"protein":0,"total lipid (fat)":0,"carbohydrate":0,"fiber":0,"sodium":0,"cholesterol":0}
            try:
                food_item =  re.sub('[^A-Za-z]+', ' ', food_item)
                location_name = location_names[index]
                saved_food_item_filepath = os.path.join(menu_files_folder_name + '/nutrient_'+ location_name + '_' + food_item.replace(" ", "_") + '.json')
                if not os.path.exists(saved_food_item_filepath):
                    report = usda_food_search(food_item)
                    if report:
                        with open(saved_food_item_filepath, 'w+') as file:
                            json.dump(report, file)

            except:
                continue
            

scan_food_item_from_main_section(validation_set)

# %% [markdown]
# ## 3. Perform Nutrition Analysis & Save to CSV
# Calculate the energy and nutrition values of each matched food items. Then, output the USDA nutrition values as well as the ground truth nutritional values of the food items to USDA. Encountered NaN values in ground truths are eliminated in the process.

# %%
# Load all nutrient report
nutrient_reports = []
nutrient_report_names = ['validation_nutrient_report_Dec_15'] #### Change the name here for the nutrient report from USDA ####
for files in nutrient_report_names:
    nutrient_reports.extend(glob.glob(os.path.join(files, "*.json")))


# Setup CSV
validation_analysis="./validation_analysis_Dec_15.csv" #### FINAL CSV filename here ####
csvfile = open(validation_analysis,'w+')
validation_analysis_f = csv.writer(csvfile)
validation_analysis_f.writerow(["Restaurant Name","Original food Item", "Matched food Item", 
                                "Match Score","Energy (KCAL)","Protein (G)","Total lipid(fat) (G)",
                                "Carbohydrate (G)","Fiber (G)","Sodium (MG)","Cholesterol (MG)",
                                "GT - Energy (KCAL)", "GT - Protein (G)","GT - Total lipid(fat) (G)",
                                "GT - Carbohydrate (G)"])

# Average all nutrient content 
food_score_threshold = 25

for report in nutrient_reports:
    energy, protein, total_lipid, carbohydrate, fiber, sodium, cholesterol = [],[],[],[],[],[],[] 
    with open(str(report)) as input_file:
        filename = report.split('/')[-1].split('_')
        location_name = filename[1]
        food = report.split('/')[-1].split('.json')[0].split(location_name)[-1].replace('_', ' ').lstrip()
        data = json.load(input_file)
        
        if 'foods' in data:
            food_benchmark = data["foods"]
            match_food_items = []
            pos_correlated_food_search = []
            match_food_score = 0
            for food_item in food_benchmark:
                pos_correlated_food_search.append(False)
                match_food_items.append(food_item['description'])
                match_food_score += food_item['score']
                food_nutrients = food_item['foodNutrients']

                # Calculate food value if matched food item is positively correlated to original food item
                if food_nutrients and match_food_score > food_score_threshold:
                    pos_correlated_food_search.append(True)
                    for food_nutrient in food_nutrients:
                        if food_nutrient['nutrientId'] == 1003:
                            protein.append(food_nutrient['value'])
                        if food_nutrient['nutrientId'] == 1004:
                            total_lipid.append(food_nutrient['value'])
                        if food_nutrient['nutrientId'] == 1008:
                            energy.append(food_nutrient['value'])
                        if food_nutrient['nutrientId'] == 1005:
                            carbohydrate.append(food_nutrient['value'])
                        if food_nutrient['nutrientId'] == 1079:
                            fiber.append(food_nutrient['value'])
                        if food_nutrient['nutrientId'] == 1093:
                            sodium.append(food_nutrient['value'])
                        if food_nutrient['nutrientId'] == 1253:
                            cholesterol.append(food_nutrient['value'])
    
    # Calculate the average nutrients
    if np.array(pos_correlated_food_search).any():
        average_protein = sum(protein) / len(protein) if len(protein) > 0 else 0
        average_total_lipid = sum(total_lipid) / len(total_lipid) if len(total_lipid) > 0 else 0
        average_energy = sum(energy) / len(energy) if len(energy) > 0 else 0
        average_carbohydrate = sum(carbohydrate) / len(carbohydrate) if len(carbohydrate) > 0 else 0
        average_fiber = sum(fiber) / len(fiber) if len(fiber) > 0 else 0
        average_sodium = sum(sodium) / len(sodium) if len(sodium) > 0 else 0
        average_cholesterol = sum(cholesterol) / len(cholesterol) if len(cholesterol) > 0 else 0
        average_match_food_score = match_food_score / len(match_food_items) * 1.0 if match_food_score != 0 else 0       
        
        valid_food_item = validation_set[' Item_Name_2018'].str.replace(r'[^A-Za-z]+', ' ')
        matched_food_criteria = ((valid_food_item == food) & (validation_set.Restaurant == location_name))
        gt_average_energy = validation_set.loc[matched_food_criteria, 'Calories_2018'].values[0] if validation_set.loc[matched_food_criteria, 'Calories_2018'].values.size > 0 else None
        gt_average_protein = validation_set.loc[matched_food_criteria, 'Protein_2018'].values[0] if validation_set.loc[matched_food_criteria, 'Protein_2018'].values.size > 0 else None
        gt_average_total_lipid = validation_set.loc[matched_food_criteria, 'Total_Fat_2018'].values[0] if validation_set.loc[matched_food_criteria, 'Total_Fat_2018'].values.size > 0 else None
        gt_average_carbohydrate = validation_set.loc[matched_food_criteria, 'Carbohydrates_2018'].values[0] if validation_set.loc[matched_food_criteria, 'Carbohydrates_2018'].values.size > 0 else None
        
        validation_analysis_f.writerow([location_name, food, match_food_items, average_match_food_score, average_energy, 
                                  average_protein, average_total_lipid, average_carbohydrate, average_fiber, 
                                  average_sodium, average_cholesterol, gt_average_energy, gt_average_protein, 
                                  gt_average_total_lipid, gt_average_carbohydrate])

# %%
nutrient_pd = pd.read_csv(validation_analysis) 
# drop Nan values
nutrient_plt = nutrient_pd.replace(np.nan, '', regex=True).dropna()
print('This table contains: {} rows x {} cols.'.format(nutrient_plt.shape[0], nutrient_plt.shape[1]))
nutrient_plt.head(50)
# Out:
# This table contains: 15419 rows x 15 cols.
#                 Restaurant Name  \
# 0                       Chili's
# 1                          Wawa
# 2                Dunkin' Donuts
# 3                   Tim Hortons
# 4           LongHorn Steakhouse
# 5            The Capital Grille
# 6   BJ's Restaurant & Brewhouse
# 7                Dunkin' Donuts
# 8                          Wawa
# 9                Dunkin' Donuts
# 10      Romano's Macaroni Grill
# 11                   Friendly's
# 12               Baskin Robbins
# 13                       Sheetz
# 14     Carrabba's Italian Grill
# 15  BJ's Restaurant & Brewhouse
# 16                  Chick-Fil-A
# 17                    Starbucks
# 18                    Bojangles
# 19                     Del Taco
# 20  BJ's Restaurant & Brewhouse
# 21                      Dominos
# 22                 Panera Bread
# 23                Panda Express
# 24        Dickey's Barbeque Pit
# 25                    Bob Evans
# 26                      Chili's
# 27                  Dairy Queen
# 28                 Panera Bread
# 29               Baskin Robbins
# 30                     Culver's
# 31                       Subway
# 32                 Panera Bread
# 33             Frisch's Big Boy
# 34            Round Table Pizza
# 35                    Taco Bell
# 36                 TGI Friday's
# 37                   Applebee's
# 38                  Papa John's
# 39                 White Castle
# 40               Bonefish Grill
# 41              Chuck E. Cheese
# 42                  Papa John's
# 43     Carrabba's Italian Grill
# 44                Boston Market
# 45                      Denny's
# 46  BJ's Restaurant & Brewhouse
# 47           Long John Silver's
# 48                  Whataburger
# 49                  Whataburger
#
#                                    Original food Item  \
# 0                       Classic Nachos Fajita Chicken
# 1                             Cinnamon Sugar Twist FL
# 2                                    Original Kolache
# 3                               Oatmeal Maple Regular
# 4                                  Raspberry Iced Tea
# 5                           Adults Only Arnold Palmer
# 6                                EXXXXtra Hot Buffalo
# 7   Winter White Chocolate Swirl Hot Latte w Whole...
# 8                                Hot Vanilla Latte oz
# 9    Peppermint Mocha Swirl Iced Coffee w Cream Large
# 10                 Prosciutto Grilled Cheese Sandwich
# 11                           New England Fish N Chips
# 12                       Made w Snickers Below Medium
# 13                                         Bacon Melt
# 14                            Italian Salad w Chicken
# 15                      Mini Chocolate Chunk Pizookie
# 16                                         Cobb Salad
# 17                            Pike Place Roast Grande
# 18                                Simply Orange Juice
# 19                 Flatbread Taco w Carne Asada Steak
# 20  Black Olives for Topping Build Your Own Deep D...
# 21                       Cinnamon Bread Twists Pieces
# 22                          Panera Decaf Coffee Large
# 23                                  Hot Szechuan Tofu
# 24                                           Lays BBQ
# 25                  Hearty Beef Vegetable Family Size
# 26                           Ultimate Fresh Margarita
# 27                          Heath Blizzard Treat Mini
# 28  Avocado Egg White Spinach Breakfast Power Sand...
# 29      Old Fashioned Butter Pecan Ice Cream oz Scoop
# 30                        Cheddar ButterBurger Triple
# 31                         Mega Melt w Regular Egg in
# 32                   Lipton Brisk Raspberry Tea Large
# 33                                              Bacon
# 34     Smokehouse Combo Chicken on Skinny Crust Small
# 35            Nacho Cheese Doritos Double Decker Taco
# 36                                      Lagunitas IPA
# 37                                         Applesauce
# 38                      Double Chocolate Chip Brownie
# 39                                      Coffee Medium
# 40                          Henry Weinhards Root Beer
# 41                             Garden Fresh Salad Bar
# 42  Grilled Chicken Canadian Bacon Pizza on Origin...
# 43          Mamma Mandolas Sicilian Chicken Soup Kids
# 44                                Caesar Salad Entree
# 45                                  Creamer Half Half
# 46  Roasted Garlic for Topping Build Your Own Deep...
# 47                             Diet Pepsi Small fl oz
# 48                           Biscuit Sandwich w Bacon
# 49               Minute Maid Light Lemonade Medium oz
#
#                                     Matched food Item  Match Score  \
# 0   ['CLASSIC FAJITA SIMMER SAUCE, CLASSIC FAJITA'...    61.966458
# 1   ['CINNAMON & SUGAR TWISTED PRETZELS, CINNAMON ...    49.946345
# 2   ['SAUSAGE KOLACHE', 'KOLACHES SMOKED SAUSAGE',...  -224.091143
# 3   ['INSTANT REGULAR OATMEAL, REGULAR', 'REGULAR ...    83.731024
# 4   ['RASPBERRY ICED TEA, RASPBERRY', 'RASPBERRY I...   143.203472
# 5   ['NATURAL ENERGY ARNOLD PALMER', 'ARIZONA, ARN...   -10.910259
# 6   ['HOT BUFFALO FLAVORED POPCORN, HOT BUFFALO', ...    26.389151
# 7   ['WHITE & MILK CHOCOLATE SWIRL', 'SIMPLY SMALL...   118.936525
# 8   ['VANILLA LATTE COFFEE, VANILLA LATTE', 'VANIL...    68.871408
# 9   ['PEPPERMINT MOCHA COFFEE CREAMER, PEPPERMINT ...   379.695392
# 10  ['GRILLED CHICKEN & PROSCIUTTO RAVIOLI, GRILLE...    87.688356
# 11  ['NEW ENGLAND BAKED COD FISH FILLETS, NEW ENGL...   260.110356
# 12  ['SNICKERS, SNICKERS', 'SNICKERS, SNICKERS MIN...   -18.043818
# 13  ['TRIPLE CHEESY BACON MELT SANDWICHES, TRIPLE ...   -61.675985
# 14  ['CHICKEN CAESAR CONEWHICH, CHICKEN CAESAR SAL...     9.768932
# 15  ['MINI CHOCOLATE CHUNK COOKIES, MINI CHOCOLATE...   -12.071889
# 16  ['COBB SALAD', 'COBB SALAD', 'COBB SALAD', 'CO...   589.815923
# 17  ['WHITEFISH & PIKE', 'WHITEFISH & PIKE', 'WHIT...   -49.882587
# 18  ['SIMPLY ORANGE, ORANGE JUICE', 'SIMPLY ORANGE...    23.387159
# 19  ['CARNE ASADA STEAK STREET TACO MIX, CARNE ASA...   542.865624
# 20  ['DEEP DISH MINI PIZZA', 'DEEP DISH MINI PIZZA...   579.655703
# 21  ['CINNAMON TWIST MUESLI, CINNAMON TWIST', 'CIN...    32.609192
# 22  ['DECAF COFFEE', 'DECAFE COFFEE', 'COLD BREW D...    12.663141
# 23  ['SZECHUAN MAPO TOFU SALAD', 'SZECHUAN, HOT BE...    10.070242
# 24  ["1.87OZ LAY'S HONEY BBQ", "LAY'S, WAVY POTATO...  -106.397745
# 25  ['MIXED VEGETABLES FAMILY SIZE', 'HEARTY VEGET...   154.261132
# 26  ['NATURAL ULTIMATE MARGARITA MIX', 'MARGARITA ...   -12.009635
# 27  ['BLIZZARD MIX', 'BLIZZARD CHERRY BERRY SMOOTH...   -67.789691
# 28  ['FLATBREAD BREAKFAST SANDWICH, EGG, SPINACH, ...   164.551499
# 29  ['BUTTER PECAN OLD FASHIONED ICE CREAM, BUTTER...   374.585668
# 30  ['SHREDDED TRIPLE CHEDDAR CHEESE, TRIPLE CHEDD...   -55.335705
# 31  ['L&W, QUAIL EGGS', 'AUNT JEMIMA, GRIDDLE MELT...   -55.676646
# 32  ['LIPTON, ICED TEA, RASPBERRY, RASPBERRY', 'LI...   118.240556
# 33  ['BACON', 'BACON', 'BACON', 'BACON', 'BACON', ...   407.712497
# 34  ['SMOKEHOUSE SEASONED CHICKEN BREASTS, SMOKEHO...    21.939721
# 35  ['CHEESY DOUBLE DECKER TACO DINNER KIT, CHEESY...   263.517302
# 36  ['IPA CHILI SEASONING, IPA CHILI', 'IPA SHANDY...  -187.251004
# 37  ['APPLESAUCE', 'APPLESAUCE', 'APPLESAUCE', 'AP...   680.334960
# 38  ['DOUBLE CHOCOLATE CHIP BROWNIE BITES', 'DOUBL...   235.024922
# 39  ['MEDIUM ROAST COFFEE', 'MEDIUM ROAST COFFEE',...   -73.893980
# 40  ['HENRY WEINHARD, CREAM SODA, BLACK CHERRY', '...   275.475490
# 41  ['FRESH GARDEN SALAD', 'FRESH MINI CLASSIC GAR...   156.414970
# 42  ['CANADIAN BACON ORIGINAL PIZZA, CANADIAN BACO...   311.451064
# 43  ['PREMIUM SICILIAN LENTIL SOUP', 'KIDS COOL SH...   -16.822131
# 44  ['DELUXE CHICKEN CAESAR WITH CREAMY CAESAR DRE...   138.095230
# 45  ['HALF & HALF CREAMERS, HALF & HALF', 'HALF & ...   520.368753
# 46  ['DEEP DISH PIZZA', 'DEEP DISH PIZZA', 'DEEP D...   526.923985
# 47  ['PEPSI NEXT 12 FL OZ CAN', 'Diet Coke Bottle,...   184.412472
# 48  ['BACON, EGG & CHEESE BISCUIT SANDWICH', 'BISC...    90.867339
# 49  ['MINUTE MAID, LIGHT LEMONADE, LEMONADE', 'MIN...   329.858015
#
#     Energy (KCAL)  Protein (G)  Total lipid(fat) (G)  Carbohydrate (G)  \
# 0      119.541667    10.335000              2.780000         11.904167
# 1      376.080000     4.066800              9.750800        243.879600
# 2      294.400000     9.116000             14.700000         32.580000
# 3      357.360000    11.743600              7.616400         62.939200
# 4       81.600000     0.000000              0.000000         21.019000
# 5      283.272727     2.525909              9.127273         50.837273
# 6      203.142857     7.412381             13.917000         14.262000
# 7      338.375000     5.343333             19.121250         38.022083
# 8      249.583333    11.302500              9.553750         32.370000
# 9      268.333333     3.507600             10.064800         40.725200
# 10     280.760000    15.506000             14.306000         24.487500
# 11     156.523810     4.753810              4.718095         24.556190
# 12     370.823529     4.411250             14.985294         53.517059
# 13     248.333333    10.218333             10.668333         27.900000
# 14     222.120000    35.335200             15.720400         12.389200
# 15     443.277778     4.777778             19.833333         62.877778
# 16     148.680000     8.363200             11.004000          3.854800
# 17     271.727273     9.031000             14.996364         26.918000
# 18      45.560000     0.593200              0.000000         11.012000
# 19     148.173913    10.120000              5.072381         18.543182
# 20     278.904762     9.258095             13.457143         29.785714
# 21     314.000000     8.002000              8.457200         51.748000
# 22     106.320000     1.100000              4.488400         15.050000
# 23     153.440000     5.909200              4.980800         13.635600
# 24     558.500000     6.395000             34.800000         56.800000
# 25     177.608696     5.203913              4.560435         30.235652
# 26     318.842105     0.855263              3.063158         61.894737
# 27     369.800000     5.196000             13.891000         53.690000
# 28     227.120000    11.145833             10.792800         21.410400
# 29     228.782609     3.064400             13.608000         27.312000
# 30     398.142857    23.457143             32.614286          5.100000
# 31     330.800000    17.008000             12.264000         38.940000
# 32      46.142857     0.000000              0.000000         12.065000
# 33     481.916667    26.902500             36.733333          9.015000
# 34     410.920000    16.054000             31.108400         19.282400
# 35     379.846154     7.021250             15.208125         54.861538
# 36     192.125000     2.352500              5.475000         27.187500
# 37      69.280000     0.000000              0.000000         17.172000
# 38     374.458333     6.653200             14.035200         61.580000
# 39     221.000000     0.370000              6.540000         39.066000
# 40      76.833333     0.000000              0.000000         18.641667
# 41      66.880000     1.457200              4.520000          5.591600
# 42     208.875000    11.357917              6.880833         24.117083
# 43     202.000000    10.200909              9.238182         23.436364
# 44     202.920000     6.349600             15.918800          9.232800
# 45     125.200000     2.427200             10.768000          2.494000
# 46     298.250000     9.178000             15.227500         30.695000
# 47       0.727273     0.001667              0.000000          0.178000
# 48     319.640000     9.274400             18.860000         28.068000
# 49      54.416667     0.099600              0.000000         14.105200
#
#     Fiber (G)   Sodium (MG)  Cholesterol (MG) GT - Energy (KCAL)  \
# 0    0.861905   2423.750000         32.095238               1480
# 1    2.306250   2314.240000         19.937500                340
# 2    1.420000    722.000000         27.800000                180
# 3    8.568000    292.640000          5.363636                220
# 4    0.000000     10.450000          0.000000                 50
# 5    0.895455    165.681818          1.318182                180
# 6    2.869231  65179.047619         41.769231                 30
# 7    2.230435    180.652174         10.136364                230
# 8    1.900000    250.458333         26.041667                 50
# 9    0.771429     90.840000          8.458333                370
# 10   1.372727    703.400000         40.640000                730
# 11   0.688235    446.666667         18.882353               1300
# 12   2.933333    318.470588          2.437500                840
# 13   0.950000    577.833333         30.166667
# 14   0.876000    447.880000         16.400000                850
# 15   2.433333    287.333333         19.055556                580
# 16   1.044000    382.160000         63.400000                250
# 17   1.155556    270.125000         28.909091                  5
# 18   0.000000      4.200000          0.000000                160
# 19   3.840000   4419.260870         26.062500                350
# 20   1.261905    572.476190         20.650000                 25
# 21   2.604167   2456.480000          7.750000                250
# 22   0.750000    112.833333         10.500000                 20
# 23   2.205556   1531.000000          2.277778                140
# 24   3.700000    429.000000          0.000000                230
# 25   2.328571    620.000000          5.428571                150
# 26   0.407143   2337.052632         12.928571                300
# 27   2.180000    275.600000          9.800000                380
# 28   2.472000    550.800000         86.200000                410
# 29   1.062500    112.880000         41.041667                160
# 30   0.514286    648.000000        101.857143                970
# 31   1.550000    771.000000         89.600000                590
# 32   0.000000      5.142857          0.000000                200
# 33   0.000000   2081.500000         99.380952                 80
# 34   5.625000    534.000000         26.227273                210
# 35   1.880000    488.538462         12.500000                320
# 36   0.480000   3146.375000          7.000000
# 37   1.240000      5.400000          0.000000                 40
# 38   5.600000    204.760000         14.458333                240
# 39   0.100000    364.400000          0.000000                  5
# 40   0.000000     11.000000          0.000000                140
# 41   1.273913   1554.840000          4.173913
# 42   1.347826    666.125000         23.583333                190
# 43   3.736364   1614.500000         22.818182                 90
# 44   1.091667    485.880000         16.920000                430
# 45   0.000000     61.280000         39.840000                 15
# 46   1.090000    506.150000         20.300000                  0
# 47   0.000000      9.920000          0.000000                  0
# 48   1.360000    642.680000         69.720000                470
# 49   0.007692     18.640000          0.000000                 20
#
#    GT - Protein (G) GT - Total lipid(fat) (G) GT - Carbohydrate (G)
# 0                99                        95                    57
# 1                 7                        14                    47
# 2                10                         9                    20
# 3                 5                       2.5                    49
# 4                 0                         0                    13
# 5                15                         0                   110
# 6                 1                         1                     6
# 7                 8                         6                    36
# 8                 0                         0                    14
# 9                 4                        12                    63
# 10               42                        38                    51
# 11               40                        80                    90
# 12               23                        36                   108
# 13
# 14               34                        68                    26
# 15                7                        23                    86
# 16               12                        15                    18
# 17                1                         0                     0
# 18                2                         0                    37
# 19               17                        15                    34
# 20                0                         2                     1
# 21                5                        12                    31
# 22                2                         0                     3
# 23                6                         8                    10
# 24                0                        15                    23
# 25                8                       3.5                    24
# 26                0                         0                    45
# 27                8                        15                    53
# 28               12                        14                    52
# 29                3                        11                    13
# 30               63                        64                    39
# 31               35                        29                    45
# 32                0                         0                    52
# 33                5                         7                     0
# 34               12                        11                    17
# 35               14                        13                    36
# 36
# 37                0                         0                    10
# 38                2                        12                    34
# 39                1                         0                     0
# 40                0                         0                    36
# 41
# 42                9                       4.5                    26
# 43                7                         2                    10
# 44               34                        28                    15
# 45                0                         1                     1
# 46                0                         0                     1
# 47                0                         0                     0
# 48               18                        29                    32
# 49                0                         0                     5

# %% [markdown]
# ## 4. Ground Truth Analysis

# %% [markdown]
# #### 4.1 Mean Square Error

# %%
from sklearn.metrics import mean_squared_error

# remove nan value
nan_value = float("NaN")
nutrient_plt.replace("", nan_value, inplace=True)
nutrient_plt.dropna(subset = ['GT - Energy (KCAL)', 'GT - Protein (G)', 'GT - Total lipid(fat) (G)', 'GT - Carbohydrate (G)'], inplace=True)
nutrient_plt['GT - Energy (KCAL)'].astype(float)

rms_calorie = np.sqrt(mean_squared_error(nutrient_plt['Energy (KCAL)'], nutrient_plt['GT - Energy (KCAL)']))
print("MSE in term of calories (Kcal): {}".format(rms_calorie))
rms_protein = np.sqrt(mean_squared_error(nutrient_plt['Protein (G)'], nutrient_plt['GT - Protein (G)']))
print("MSE in term of protein (g): {}".format(rms_protein))
rms_fat = np.sqrt(mean_squared_error(nutrient_plt['Total lipid(fat) (G)'], nutrient_plt['GT - Total lipid(fat) (G)']))
print("MSE in term of lipid (g): {}".format(rms_fat))
rms_carb = np.sqrt(mean_squared_error(nutrient_plt[ 'Carbohydrate (G)'], nutrient_plt['GT - Carbohydrate (G)']))
print("MSE in term of carbohydrates (g): {}".format(rms_carb))
# Out:
# MSE in term of calories (Kcal): 454.2299121332706
# MSE in term of protein (g): 21.66618011965543
# MSE in term of lipid (g): 26.911182334418733
# MSE in term of carbohydrates (g): 52.46931891387338

# %% [markdown]
# #### 4.2 Correlation Matrix

# %%
import seaborn as sn
import matplotlib.pyplot as plt

ground_truth_df = pd.DataFrame(nutrient_pd, columns=['Energy (KCAL)', 'Protein (G)', 'Total lipid(fat) (G)', 'Carbohydrate (G)', 'GT - Energy (KCAL)', 'GT - Protein (G)', 'GT - Total lipid(fat) (G)', 'GT - Carbohydrate (G)'])
corrMatrix = ground_truth_df.corr()
print(corrMatrix)

sn.heatmap(corrMatrix, annot=True)
plt.show()
# Out:
#                            Energy (KCAL)  Protein (G)  Total lipid(fat) (G)  \
# Energy (KCAL)                   1.000000     0.428040              0.763030
# Protein (G)                     0.428040     1.000000              0.326153
# Total lipid(fat) (G)            0.763030     0.326153              1.000000
# Carbohydrate (G)                0.733150     0.094431              0.182194
# GT - Energy (KCAL)              0.145759     0.191536              0.106546
# GT - Protein (G)                0.044951     0.296643              0.055081
# GT - Total lipid(fat) (G)       0.152124     0.216596              0.186889
# GT - Carbohydrate (G)           0.130163     0.043983              0.002520
#
#                            Carbohydrate (G)  GT - Energy (KCAL)  \
# Energy (KCAL)                      0.733150            0.145759
# Protein (G)                        0.094431            0.191536
# Total lipid(fat) (G)               0.182194            0.106546
# Carbohydrate (G)                   1.000000            0.080235
# GT - Energy (KCAL)                 0.080235            1.000000
# GT - Protein (G)                  -0.063875            0.773149
# GT - Total lipid(fat) (G)          0.008138            0.912478
# GT - Carbohydrate (G)              0.196136            0.740810
#
#                            GT - Protein (G)  GT - Total lipid(fat) (G)  \
# Energy (KCAL)                      0.044951                   0.152124
# Protein (G)                        0.296643                   0.216596
# Total lipid(fat) (G)               0.055081                   0.186889
# Carbohydrate (G)                  -0.063875                   0.008138
# GT - Energy (KCAL)                 0.773149                   0.912478
# GT - Protein (G)                   1.000000                   0.756601
# GT - Total lipid(fat) (G)          0.756601                   1.000000
# GT - Carbohydrate (G)              0.376009                   0.497250
#
#                            GT - Carbohydrate (G)
# Energy (KCAL)                           0.130163
# Protein (G)                             0.043983
# Total lipid(fat) (G)                    0.002520
# Carbohydrate (G)                        0.196136
# GT - Energy (KCAL)                      0.740810
# GT - Protein (G)                        0.376009
# GT - Total lipid(fat) (G)               0.497250
# GT - Carbohydrate (G)                   1.000000

# %% [markdown]
# #### 4.3 Density Distribution & Scatter plot
# Density Distribution generate kernel density estimate using gaussian kernels

# %% [markdown]
# #### Average Energy (Kcal)

# %%
calories_plt = nutrient_plt[["Energy (KCAL)", "GT - Energy (KCAL)"]]

# remove nan value
# nan_value = float("NaN")
# calories_plt.replace("", nan_value, inplace=True)
# calories_plt.dropna(subset = ['GT - Energy (KCAL)'], inplace=True)
# calories_plt['Energy (KCAL)'].astype(float)
# calories_plt['GT - Energy (KCAL)'].astype(float)

ax = calories_plt.plot.kde()
plt.xlim([0,2000])  
plt.title('Distribution of food items by Average Calories')
plt.xlabel('Calories')
plt.ylabel('Density')

ax2 = calories_plt.plot.scatter(x='Energy (KCAL)', y='GT - Energy (KCAL)')
plt.title('Scatter Plot of food items by Average Calories')
# Out:
# Text(0.5, 1.0, 'Scatter Plot of food items by Average Calories')

# %% [markdown]
# #### Carbonhydrates (g)

# %%
carb_plt = nutrient_plt[["Carbohydrate (G)", "GT - Carbohydrate (G)"]]

# remove nan value
# nan_value = float("NaN")
# carb_plt.replace("", nan_value, inplace=True)
# carb_plt.dropna(subset = ["GT - Carbohydrate (G)"], inplace=True)
# carb_plt["Carbohydrate (G)"].astype(float)
# carb_plt["GT - Carbohydrate (G)"].astype(float)

ax = carb_plt.plot.kde()
plt.xlim([0,150])  
plt.title('Distribution of food items by Carbonhydrates (g)')
plt.xlabel('Carbonhydrates (g)')
plt.ylabel('Density')

ax2 = carb_plt.plot.scatter(x="Carbohydrate (G)", y="GT - Carbohydrate (G)")
plt.title('Scatter Plot of food items by Carbonhydrates (g)')
# Out:
# Text(0.5, 1.0, 'Scatter Plot of food items by Carbonhydrates (g)')

# %% [markdown]
# #### Lipid (g)

# %%
lipid_plt = nutrient_plt[["Total lipid(fat) (G)", "GT - Total lipid(fat) (G)"]]

# remove nan value
# nan_value = float("NaN")
# lipid_plt.replace("", nan_value, inplace=True)
# lipid_plt.dropna(subset = ["GT - Total lipid(fat) (G)"], inplace=True)
# lipid_plt["Total lipid(fat) (G)"].astype(float)
# lipid_plt["GT - Total lipid(fat) (G)"].astype(float)

ax = lipid_plt.plot.kde()
plt.xlim([0,150])  
plt.title('Distribution of food items by Lipid (g)')
plt.xlabel('Lipid (g)')
plt.ylabel('Density')

ax2 = lipid_plt.plot.scatter(x="Total lipid(fat) (G)", y="GT - Total lipid(fat) (G)")
plt.title('Scatter Plot of food items by Lipid (g)')
# Out:
# Text(0.5, 1.0, 'Scatter Plot of food items by Lipid (g)')

# %% [markdown]
# #### Protein (g)

# %%
protein_plt = nutrient_plt[["Protein (G)", "GT - Protein (G)"]]

# remove nan value
# nan_value = float("NaN")
# protein_plt.replace("", nan_value, inplace=True)
# protein_plt.dropna(subset = ["GT - Protein (G)"], inplace=True)
# protein_plt["Protein (G)"].astype(float)
# protein_plt["GT - Protein (G)"].astype(float)

ax = protein_plt.plot.kde()
plt.xlim([0,150])  
plt.title('Distribution of food items by Protein (g)')
plt.xlabel('Protein (g)')
plt.ylabel('Density')
ax2 = protein_plt.plot.scatter(x="Protein (G)", y="GT - Protein (G)")
plt.title('Scatter Plot of food items by Protein (g)')
# Out:
# Text(0.5, 1.0, 'Scatter Plot of food items by Protein (g)')

# %% [markdown]
# ### Summary
#
# With ground truth analysis, we can conclude the following few points:
#
# 1. It is observed some discrepancy between the real values between the ground truths and the obtained nutritional values in terms of calories, carbohydrates, lipids and proteins
# 2. MSE in term of calories is 454.2. It reflected a huge error betweent the ground truth and the obtained values. Reasons for that may be resulted from different serving size metric between the ground truth and the USDA nutritional value.
